# %% [markdown]
# Preprocess Data

# %%
import pandas as pd
df = pd.read_csv('final_dataset.csv', low_memory=False)

numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns
print(numeric_columns)

df.head()
# Out:
# Index(['academicYear', 'idOSYM', 'scholarshipRate', 'quota', 'occupiedSlots',
#        'tuitionFee', 'profCount', 'assoCount', 'docCount', 'baseRanking',
#        'topRanking', 'avgAdmissionRanking(TYT)', 'baseAdmissionRanking(TYT)',
#        'stdDeviationStudents', 'revenue', 'outOfCityStudentRate',
#        'totalPreference', 'top1PreferenceRatio', 'avgOrderofPreference',
#        'avgAdmittedStudentPrefOrder', 'top1AdmittedRatio', 'top3AdmittedRatio',
#        'top10AdmittedRatio', 'admittedTotalPref',
#        'admittedTotalDepartmentPref', 'currentStudentCount', 'baseScore',
#        'topScore', 'totalForeignStudents', 'totalStudentNumber', 'Urap_Rank',
#        'Urap_Score', 'avg_monthly_income_group', 'Time_for_employment',
#        'employment_rate', 'base_salary_by_year', 'inflation_by_year',
#        'growth_by_year'],
#       dtype='object')
#    academicYear           universityName universityType  \
# 0          2024  İBN HALDUN ÜNİVERSİTESİ          vakıf
# 1          2023  İBN HALDUN ÜNİVERSİTESİ          vakıf
# 2          2022  İBN HALDUN ÜNİVERSİTESİ          vakıf
# 3          2021  İBN HALDUN ÜNİVERSİTESİ          vakıf
# 4          2020  İBN HALDUN ÜNİVERSİTESİ          vakıf
#
#                      faculty departmentName     idOSYM programType   language  \
# 0  yönetimbilimlerifakültesi       i̇şletme  208610078          EA  İngilizce
# 1  yönetimbilimlerifakültesi       i̇şletme  208610078          EA  İngilizce
# 2  yönetimbilimlerifakültesi       i̇şletme  208610078          EA  İngilizce
# 3  yönetimbilimlerifakültesi       i̇şletme  208610078          EA  İngilizce
# 4  yönetimbilimlerifakültesi       i̇şletme  208610078          EA  İngilizce
#
#    scholarshipRate  quota  ...  totalForeignStudents  totalStudentNumber  \
# 0            100.0      8  ...                 508.0               861.0
# 1            100.0      8  ...                 508.0               861.0
# 2            100.0     10  ...                 508.0               861.0
# 3            100.0     10  ...                 508.0               861.0
# 4            100.0     10  ...                 508.0               861.0
#
#   Urap_Rank  Urap_Score  avg_monthly_income_group  Time_for_employment  \
# 0     112.0  492.920000                       0.0                 18.5
# 1     123.0  494.510000                       0.0                 18.5
# 2     145.0  392.554937                       0.0                 19.8
# 3     148.0  266.210000                       0.0                 19.8
# 4     136.0  260.440000                       0.0                 19.8
#
#    employment_rate  base_salary_by_year  inflation_by_year  growth_by_year
# 0             74.0                17002               64.0             2.7
# 1             74.0                11402               64.0             3.8
# 2             74.4                 5500               64.0             5.4
# 3             74.4                 2825               36.0            11.6
# 4             74.4                 2103               14.0             1.8
#
# [5 rows x 46 columns]

# %%
non_numeric_columns = df.select_dtypes(exclude=['number']).columns
print(non_numeric_columns)
# Out:
# Index(['universityName', 'universityType', 'faculty', 'departmentName',
#        'programType', 'language', 'universityLocation', 'universityRegion'],
#       dtype='object')

# %%
numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns

non_numeric_counts = {}
missing_counts = {}

for col in numeric_columns:
    non_numeric_counts[col] = df[col].apply(pd.to_numeric, errors='coerce').isnull().sum()
    missing_counts[col] = df[col].isnull().sum()

# Print non-numeric and missing value counts
print("Non-numeric value counts in numeric columns:")
print(non_numeric_counts)
print("\nMissing value counts in numeric columns:")
print(missing_counts)

# Get summary statistics for numeric columns
summary_statistics = df[numeric_columns].describe()
print("\nSummary statistics for numeric columns:")
print(summary_statistics)
# Out:
# Non-numeric value counts in numeric columns:
# {'academicYear': np.int64(0), 'idOSYM': np.int64(0), 'scholarshipRate': np.int64(0), 'quota': np.int64(0), 'occupiedSlots': np.int64(0), 'tuitionFee': np.int64(0), 'profCount': np.int64(0), 'assoCount': np.int64(0), 'docCount': np.int64(0), 'baseRanking': np.int64(0), 'topRanking': np.int64(0), 'avgAdmissionRanking(TYT)': np.int64(0), 'baseAdmissionRanking(TYT)': np.int64(0), 'stdDeviationStudents': np.int64(0), 'revenue': np.int64(0), 'outOfCityStudentRate': np.int64(0), 'totalPreference': np.int64(0), 'top1PreferenceRatio': np.int64(0), 'avgOrderofPreference': np.int64(0), 'avgAdmittedStudentPrefOrder': np.int64(0), 'top1AdmittedRatio': np.int64(0), 'top3AdmittedRatio': np.int64(0), 'top10AdmittedRatio': np.int64(0), 'admittedTotalPref': np.int64(0), 'admittedTotalDepartmentPref': np.int64(0), 'currentStudentCount': np.int64(0), 'baseScore': np.int64(0), 'topScore': np.int64(0), 'totalForeignStudents': np.int64(0), 'totalStudentNumber': np.int64(0), 'Urap_Rank': np.int64(0), 'Urap_Score': np.int64(0), 'avg_monthly_income_group': np.int64(0), 'Time_for_employment': np.int64(0), 'employment_rate': np.int64(0), 'base_salary_by_year': np.int64(0), 'inflation_by_year': np.int64(0), 'growth_by_year': np.int64(0)}
#
# Missing value counts in numeric columns:
# {'academicYear': np.int64(0), 'idOSYM': np.int64(0), 'scholarshipRate': np.int64(0), 'quota': np.int64(0), 'occupiedSlots': np.int64(0), 'tuitionFee': np.int64(0), 'profCount': np.int64(0), 'assoCount': np.int64(0), 'docCount': np.int64(0), 'baseRanking': np.int64(0), 'topRanking': np.int64(0), 'avgAdmissionRanking(TYT)': np.int64(0), 'baseAdmissionRanking(TYT)': np.int64(0), 'stdDeviationStudents': np.int64(0), 'revenue': np.int64(0), 'outOfCityStudentRate': np.int64(0), 'totalPreference': np.int64(0), 'top1PreferenceRatio': np.int64(0), 'avgOrderofPreference': np.int64(0), 'avgAdmittedStudentPrefOrder': np.int64(0), 'top1AdmittedRatio': np.int64(0), 'top3AdmittedRatio': np.int64(0), 'top10AdmittedRatio': np.int64(0), 'admittedTotalPref': np.int64(0), 'admittedTotalDepartmentPref': np.int64(0), 'currentStudentCount': np.int64(0), 'baseScore': np.int64(0), 'topScore': np.int64(0), 'totalForeignStudents': np.int64(0), 'totalStudentNumber': np.int64(0), 'Urap_Rank': np.int64(0), 'Urap_Score': np.int64(0), 'avg_monthly_income_group': np.int64(0), 'Time_for_employment': np.int64(0), 'employment_rate': np.int64(0), 'base_salary_by_year': np.int64(0), 'inflation_by_year': np.int64(0), 'growth_by_year': np.int64(0)}
#
# Summary statistics for numeric columns:
#        academicYear        idOSYM  scholarshipRate         quota  \
# count  65281.000000  6.528100e+04     65281.000000  65281.000000
# mean    2021.387494  1.561391e+08        34.840153     42.189213
# std        1.656787  4.918308e+07        42.376832     79.055275
# min     2019.000000  1.001100e+08         0.000000      1.000000
# 25%     2020.000000  1.059901e+08         0.000000     10.000000
# 50%     2021.000000  2.002117e+08         0.000000     31.000000
# 75%     2023.000000  2.035109e+08       100.000000     60.000000
# max     2024.000000  2.104028e+08       100.000000   5800.000000
#
#        occupiedSlots     tuitionFee     profCount     assoCount      docCount  \
# count   65281.000000   65281.000000  65281.000000  65281.000000  65281.000000
# mean       39.477919   21515.436651      4.436972      2.272315      4.603958
# std        75.090910   61179.402784     16.775925      6.209035      7.902867
# min         1.000000       0.000000      0.000000      0.000000      0.000000
# 25%         8.000000       0.000000      0.000000      0.000000      2.000000
# 50%        29.000000       0.000000      1.000000      1.000000      3.000000
# 75%        60.000000   15408.846154      3.000000      2.000000      5.000000
# max      5945.000000  945000.000000    321.000000    106.000000    110.000000
#
#         baseRanking  ...  totalForeignStudents  totalStudentNumber  \
# count  6.528100e+04  ...          65281.000000        65281.000000
# mean   3.058504e+05  ...           1826.486558        13887.947443
# std    3.125379e+05  ...           2167.337997         9877.920381
# min    0.000000e+00  ...              0.000000            0.000000
# 25%    7.079100e+04  ...            392.000000         6200.000000
# 50%    2.125470e+05  ...           1093.000000        12278.000000
# 75%    4.359490e+05  ...           2210.000000        19243.000000
# max    1.859415e+06  ...          15755.000000        43610.000000
#
#           Urap_Rank    Urap_Score  avg_monthly_income_group  \
# count  65281.000000  65281.000000              65281.000000
# mean      77.689680    471.828369                 -0.318494
# std       53.997018    227.955732                  1.233658
# min        0.000000      0.000000                 -2.000000
# 25%       31.000000    319.040000                 -1.000000
# 50%       70.000000    467.020000                 -0.334579
# 75%      126.000000    625.400000                  0.000000
# max      190.000000   1126.410000                  2.000000
#
#        Time_for_employment  employment_rate  base_salary_by_year  \
# count         65281.000000     65281.000000          65281.00000
# mean             13.690797        75.979761           6355.19799
# std               3.838988         8.877688           5468.29917
# min               2.300000        39.700000           2103.00000
# 25%              11.300000        71.000000           2103.00000
# 50%              13.600000        75.717605           2825.00000
# 75%              16.000000        82.700000          11402.00000
# max              24.500000        96.200000          17002.00000
#
#        inflation_by_year  growth_by_year
# count       65281.000000    65281.000000
# mean           40.292851        4.642078
# std            22.598085        3.865242
# min            11.800000        0.700000
# 25%            14.000000        1.800000
# 50%            36.000000        3.800000
# 75%            64.000000        5.400000
# max            64.000000       11.600000
#
# [8 rows x 38 columns]

# %% [markdown]
# Encoding Non-numeric Values

# %%
print('Non-numeric columns:', non_numeric_columns)
# Out:
# Non-numeric columns: Index(['universityName', 'universityType', 'faculty', 'departmentName',
#        'programType', 'language', 'universityLocation', 'universityRegion'],
#       dtype='object')

# %%
from sklearn.preprocessing import OneHotEncoder, LabelEncoder

# One-hot encoding
one_hot_columns = ['universityType', 'programType', 'language']
df = pd.get_dummies(df, columns=one_hot_columns)

# Label encoding
label_columns = ['universityLocation', 'universityRegion']
label_encoder = LabelEncoder()
for col in label_columns:
    df[col] = label_encoder.fit_transform(df[col])
    
# Target encoding
df['universityName_encoded'] = df.groupby('universityName')['baseRanking'].transform('mean')
df['departmentName_encoded'] = df.groupby('departmentName')['baseRanking'].transform('mean')
df['facultyName_encoded'] = df.groupby('faculty')['baseRanking'].transform('mean')

# Drop original columns
df = df.drop(['universityName', 'departmentName', 'faculty'], axis=1)
non_numeric_columns = df.select_dtypes(exclude=['number']).columns

print(non_numeric_columns)
# Out:
# Index(['universityType_devlet', 'universityType_vakıf', 'programType_DİL',
#        'programType_EA', 'programType_SAY', 'programType_SÖZ',
#        'language_Almanca', 'language_Arapça', 'language_Bulgarca',
#        'language_Ermenice', 'language_Fransızca', 'language_Korece',
#        'language_Lehçe', 'language_Rusça', 'language_Türkçe', 'language_Çince',
#        'language_İngilizce', 'language_İspanyolca', 'language_İtalyanca'],
#       dtype='object')

# %%
for col in non_numeric_columns:
    df[col] = df[col].astype(int)
non_numeric_columns = df.select_dtypes(exclude=['number']).columns
print(non_numeric_columns)
df.head()
df.to_csv('final_dataset_encoded.csv', index=False)
# Out:
# Index([], dtype='object')
